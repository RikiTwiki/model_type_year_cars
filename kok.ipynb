# %%
import torch

model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/detect/best.pt', force_reload=True)  # Adjust the path

image_path = '/home/sanarip03/Desktop/бренд_машин/10_images_for_test/081ed7500b0095f067fa7e889772f0c2_640x480.jpg'  # Update this path

results = model(image_path)

results.print()

results.save()  

results.show()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/sanarip03/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-12-21 Python-3.10.12 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7571101 parameters, 0 gradients, 17.5 GFLOPs
# Adding AutoShape...
# image 1/1: 480x640 1 Mercedes-Benz C-Class Sedan 2012
# Speed: 6.3ms pre-process, 71.0ms inference, 0.7ms NMS per image at shape (1, 3, 480, 640)
# Saved 1 image to runs/detect/exp8
# <PIL.Image.Image image mode=RGB size=640x480>
